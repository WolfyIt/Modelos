# %% [markdown]
# <a href="https://colab.research.google.com/github/WolfyIt/Modelos/blob/main/pokemon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import pandas as pd

# %%
flores_ds = pd.read_csv("/content/drive/MyDrive/DataSets/Ejercicios/Practica 2/pokemon.csv")

# %%
flores_ds
# Out:
#       pokemon_id  pokemon_name  base_attack  base_defense  base_stamina  \
# 0              1     Bulbasaur          118           111           128
# 1              2       Ivysaur          151           143           155
# 2              3      Venusaur          198           189           190
# 3              4    Charmander          116            93           118
# 4              5    Charmeleon          158           126           151
# ...          ...           ...          ...           ...           ...
# 1002        1004        Chi-Yu          269           221           146
# 1003        1005  Roaring Moon          280           196           233
# 1004        1006  Iron Valiant          279           171           179
# 1005        1007      Koraidon          263           223           205
# 1006        1008      Miraidon          263           223           205
#
#                         type     rarity  \
# 0        ['Grass', 'Poison']   Standard
# ...

# %%
flores_ds.columns
# Out:
# Index(['pokemon_id', 'pokemon_name', 'base_attack', 'base_defense',
#        'base_stamina', 'type', 'rarity', 'charged_moves', 'fast_moves',
#        'candy_required', 'distance', 'max_cp', 'attack_probability',
#        'base_capture_rate', 'base_flee_rate', 'dodge_probability',
#        'max_pokemon_action_frequency', 'min_pokemon_action_frequency',
#        'found_egg', 'found_evolution', 'found_wild', 'found_research',
#        'found_raid', 'found_photobomb'],
#       dtype='object')

# %%
import seaborn as sns

# %%
def missing (df):
    df = df.ffill().bfill()
    return df

# %%
missing(df=flores_ds)
# Out:
#       pokemon_id  pokemon_name  base_attack  base_defense  base_stamina  \
# 0              1     Bulbasaur          118           111           128
# 1              2       Ivysaur          151           143           155
# 2              3      Venusaur          198           189           190
# 3              4    Charmander          116            93           118
# 4              5    Charmeleon          158           126           151
# ...          ...           ...          ...           ...           ...
# 1002        1004        Chi-Yu          269           221           146
# 1003        1005  Roaring Moon          280           196           233
# 1004        1006  Iron Valiant          279           171           179
# 1005        1007      Koraidon          263           223           205
# 1006        1008      Miraidon          263           223           205
#
#                         type     rarity  \
# 0        ['Grass', 'Poison']   Standard
# ...

# %%
print(flores_ds['rarity'].unique())
# Out:
# ['Standard' 'Legendary' 'Mythic' 'Ultra beast']

# %%
flores_ds_numeric = flores_ds.select_dtypes(include=[float, int])
corr_mat = flores_ds_numeric.corr()
sns.heatmap(corr_mat.corr())
# Out:
# <Axes: >

# %%
sns.pairplot(flores_ds)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA (2)

# %%
res = pca.fit_transform(flores_ds[['base_attack', 'base_defense', 'base_stamina']])
flores_ds['x']= res [:,0]
flores_ds['y']= res [:,1]
flores_ds
# Out:
#       pokemon_id  pokemon_name  base_attack  base_defense  base_stamina  \
# 0              1     Bulbasaur          118           111           128
# 1              2       Ivysaur          151           143           155
# 2              3      Venusaur          198           189           190
# 3              4    Charmander          116            93           118
# 4              5    Charmeleon          158           126           151
# ...          ...           ...          ...           ...           ...
# 1002        1004        Chi-Yu          269           221           146
# 1003        1005  Roaring Moon          280           196           233
# 1004        1006  Iron Valiant          279           171           179
# 1005        1007      Koraidon          263           223           205
# 1006        1008      Miraidon          263           223           205
#
#                         type     rarity  \
# 0        ['Grass', 'Poison']   Standard
# ...

# %%
sns.scatterplot(data=flores_ds, x='x', y='y', hue='rarity')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
from sklearn.model_selection import train_test_split

# %%
flores_x = flores_ds[['base_attack', 'base_defense', 'base_stamina']]
flores_x
# Out:
#       base_attack  base_defense  base_stamina
# 0             118           111           128
# 1             151           143           155
# 2             198           189           190
# 3             116            93           118
# 4             158           126           151
# ...           ...           ...           ...
# 1002          269           221           146
# 1003          280           196           233
# 1004          279           171           179
# 1005          263           223           205
# 1006          263           223           205
#
# [1007 rows x 3 columns]

# %%
flores_y = flores_ds['rarity']

# %%
x_train, x_test, y_train, y_test = train_test_split (flores_x, flores_y, test_size=0.2, random_state=123)

# %%
x_test
# Out:
#      base_attack  base_defense  base_stamina
# 50           201           142           111
# 425          180           102           312
# 204          161           205           181
# 85            85           121           163
# 797          323           182           139
# ..           ...           ...           ...
# 698          186           163           265
# 446          127            78           120
# 338           93            82           137
# 195          261           175           163
# 79           177           180           216
#
# [202 rows x 3 columns]

# %%
from  sklearn.neighbors import KNeighborsClassifier

# %%
knn5 = KNeighborsClassifier(n_neighbors=5, metric='manhattan')

# %%
knn5.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(metric='manhattan')

# %%
knn5pred = knn5.predict(x_test)

# %%
x_test
# Out:
#      base_attack  base_defense  base_stamina
# 50           201           142           111
# 425          180           102           312
# 204          161           205           181
# 85            85           121           163
# 797          323           182           139
# ..           ...           ...           ...
# 698          186           163           265
# 446          127            78           120
# 338           93            82           137
# 195          261           175           163
# 79           177           180           216
#
# [202 rows x 3 columns]

# %%
knn5pred
# Out:
# array(['Standard', 'Standard', 'Standard', 'Standard', 'Standard',
#        'Standard', 'Mythic', 'Standard', 'Standard', 'Standard', 'Mythic',
#        'Legendary', 'Standard', 'Standard', 'Standard', 'Standard',
#        'Standard', 'Standard', 'Standard', 'Legendary', 'Standard',
#        'Standard', 'Standard', 'Standard', 'Standard', 'Standard',
#        'Standard', 'Standard', 'Standard', 'Standard', 'Standard',
#        'Standard', 'Standard', 'Standard', 'Standard', 'Standard',
#        'Standard', 'Standard', 'Standard', 'Standard', 'Legendary',
#        'Standard', 'Standard', 'Standard', 'Standard', 'Standard',
#        'Standard', 'Standard', 'Standard', 'Standard', 'Standard',
#        'Standard', 'Standard', 'Standard', 'Standard', 'Standard',
#        'Standard', 'Standard', 'Standard', 'Standard', 'Standard',
#        'Standard', 'Standard', 'Standard', 'Legendary', 'Standard',
#        'Standard', 'Standard', 'Standard', 'Standard', 'Standard',
# ...

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test, knn5pred)
# Out:
# array([[  8,   1,   5,   0],
#        [  1,   1,   2,   0],
#        [  6,   1, 174,   0],
#        [  1,   0,   2,   0]])

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, knn5pred)
# Out:
# 0.905940594059406

# %%
for k in range(1,50,2):
  knn = KNeighborsClassifier(n_neighbors=k, metric='manhattan')
  knn.fit(x_train,y_train)
  knnpred = knn.predict(x_test)
  acc=accuracy_score(y_test, knnpred)
  print(f'K={k}\tAccuracy={acc}')
# Out:
# K=1	Accuracy=0.9108910891089109
# K=3	Accuracy=0.900990099009901
# K=5	Accuracy=0.905940594059406
# K=7	Accuracy=0.8910891089108911
# K=9	Accuracy=0.900990099009901
# K=11	Accuracy=0.8861386138613861
# K=13	Accuracy=0.905940594059406
# K=15	Accuracy=0.9108910891089109
# K=17	Accuracy=0.9108910891089109
# K=19	Accuracy=0.9108910891089109
# K=21	Accuracy=0.9108910891089109
# K=23	Accuracy=0.9108910891089109
# K=25	Accuracy=0.9108910891089109
# K=27	Accuracy=0.9108910891089109
# K=29	Accuracy=0.9108910891089109
# K=31	Accuracy=0.9108910891089109
# K=33	Accuracy=0.9108910891089109
# K=35	Accuracy=0.905940594059406
# K=37	Accuracy=0.905940594059406
# K=39	Accuracy=0.905940594059406
# K=41	Accuracy=0.905940594059406
# K=43	Accuracy=0.905940594059406
# K=45	Accuracy=0.905940594059406
# K=47	Accuracy=0.905940594059406
# K=49	Accuracy=0.905940594059406

# %%
knn5 = KNeighborsClassifier(n_neighbors=9, metric='manhattan')
knn5.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(metric='manhattan', n_neighbors=9)

# %%
# Solicitar al usuario los datos
sepal_length = float(input("Ingresa la longitud del sépalo (SepalLengthCm): "))
sepal_width = float(input("Ingresa el ancho del sépalo (SepalWidthCm): "))
petal_length = float(input("Ingresa la longitud del pétalo (PetalLengthCm): "))
petal_width = float(input("Ingresa el ancho del pétalo (PetalWidthCm): "))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-155-644242189e4e> in <cell line: 2>()
#       1 # Solicitar al usuario los datos
# ----> 2 sepal_length = float(input("Ingresa la longitud del sépalo (SepalLengthCm): "))
#       3 sepal_width = float(input("Ingresa el ancho del sépalo (SepalWidthCm): "))
#       4 petal_length = float(input("Ingresa la longitud del pétalo (PetalLengthCm): "))
#       5 petal_width = float(input("Ingresa el ancho del pétalo (PetalWidthCm): "))
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# ...
